# %%
import torch

# %%
torch.autograd.set_detect_anomaly(True)

# %%
belief_updt_n_epochs = 4
belief_updt_lr = 0.1
action_slc_n_epochs = 5
action_slc_lr = 0.1
n_target = 2
mvt_amplitude = 3
max_coord = torch.tensor([300., 600.])
n_rollout = 3
n_step_per_rollout = 3
user_sigma = 5
decay_factor = 0.9

x = torch.tensor([[0.25, 0.25], [0.75, 0.75]]) * max_coord
b = torch.ones(n_target) / n_target

a = torch.nn.Parameter(torch.zeros(n_target))

a_opt = torch.optim.Adam([a, ], lr=action_slc_lr)

for _ in range(action_slc_n_epochs):

    old_a = a.clone()
    a_opt.zero_grad()
    
    # -----------------------------------
    # Build action plans
    # -----------------------------------
    
    first_action = torch.sigmoid(a)
    
    action_plan = torch.zeros((n_rollout, n_step_per_rollout, n_target))
    action_plan[:, 0] = first_action
    if n_step_per_rollout > 1:
        action_plan[:, 1:, :] = torch.rand((n_rollout, n_step_per_rollout-1, n_target)) * 360
        
    action_plan *= 360  # Convert in degrees
    
    total_efe = 0
    for rol in range(n_rollout):
        
        print("Rollout", _)
        
        efe_rollout = 0
        
        # Sample the user goal --------------------------
        
        q = torch.softmax(b, dim=0)
        goal = torch.multinomial(q, 1)[0]
        
        # -----------------------------------------------

        x_rol = x.clone()
        b_rol = b.clone()

        for step in range(n_step_per_rollout):
            
            print("STEP", step)

            action = action_plan[rol, step]

            # ---- Update positions based on action ---------------------------------------------

            x_rol_prev = x_rol.clone()

            for i in range(n_target):
                angle = action[i]
                if 90 < angle <= 270:
                    x_prime = -1
                else:
                    x_prime = 1
                y_prime = torch.tan(torch.deg2rad(angle)) * x_prime

                norm = mvt_amplitude / torch.sqrt(y_prime**2 + x_prime**2)
                movement = torch.tensor([x_prime, y_prime]) * norm
                x_rol[i] += movement

            for coord in range(2):
                for target in range(n_target):
                    if x_rol[target, coord] > max_coord[coord]:
                        x_rol[target, coord] = max_coord[coord]

            # ------------------------------------------------------------------------------            
            # Evaluate epistemic value -----------------------------------------------------
            # ------------------------------------------------------------------------------

            # Simulate action based on goal ----------------------------------------

            delta = x_rol[goal] - x_rol_prev[goal]
            noise = torch.randn(2) * user_sigma
            y = delta + noise
            
            print("y", y.detach().numpy())

            # Compute log probability of user action given a specific goal in mind -------
            logp_y = torch.zeros(n_target)
            for target in range(n_target):
                for coord in range(2):
                    d = x_rol[target, coord] - x_rol_prev[target, coord]
                    logp_coord = torch.distributions.Normal(d, user_sigma).log_prob(y[coord])
                    logp_y[target] += logp_coord
            
            logq = torch.log_softmax(b_rol - b_rol.detach().max(), dim=0)
            logp_yq = logq + logp_y

            # Revise belief -------------------
            
            print("b_rol", b_rol.detach().numpy())

            b_rol = torch.nn.Parameter(b_rol)
            b_opt = torch.optim.Adam([b_rol, ], lr=belief_updt_lr)

            for _ in range(belief_updt_n_epochs):

                old_b = b_rol.clone()
                b_opt.zero_grad()
                q_rol = torch.softmax(b_rol - b_rol.detach().max(), dim=0)
                print("q_rol", q_rol.detach().numpy())
                kl_div = torch.sum(q_rol * (q_rol.log() - logp_yq))
                kl_div.backward(retain_graph=True)
                b_opt.step()

                if torch.isclose(old_b, b_rol).all():
                    print("converged")
                    break
                    
            
            # b_rol = b_rol.detach()
            
            print("b_rol after", b_rol.detach().numpy())
            
            epistemic_value = kl_div
            
            # --------------------------------------
            # Compute extrinsic value 
            # --------------------------------------
            
            extrinsic_value = (q_rol * q_rol.log()).sum()  # minus entropy
            
            # --------------------------------------
            # Compute loss
            #---------------------------------------
            print("extrinsic_value", extrinsic_value)
            print("epistemic_value", epistemic_value)
            efe_step = - epistemic_value - extrinsic_value

            efe_rollout += decay_factor**step * efe_step

        total_efe += efe_rollout
    
    total_efe /= n_rollout
    print("big update, EFE=", total_efe)
    total_efe.backward()
    a_opt.step()
    
    print("new a", a.detach().numpy())

#     if torch.isclose(old_a, a).all():
#         print("converged")
#         break
# Out:
# Rollout 0
# STEP 0
# y [-6.2871294 -6.0726624]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# converged
# b_rol after [0.5 0.5]
# extrinsic_value tensor(-0.6931, grad_fn=<SumBackward0>)
# epistemic_value tensor(6.0104, grad_fn=<SumBackward0>)
# STEP 1
# y [ 0.28643608 10.26171   ]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# q_rol [0.549834 0.450166]
# q_rol [0.59833586 0.40166414]
# q_rol [0.6442675 0.3557325]
# b_rol after [0.89200085 0.10799922]
# extrinsic_value tensor(-0.6509, grad_fn=<SumBackward0>)
# epistemic_value tensor(7.3182, grad_fn=<SumBackward0>)
# STEP 2
# y [ 1.2001015 -0.2814257]
# b_rol [0.89200085 0.10799922]
# q_rol [0.6865419  0.31345809]
# q_rol [0.72790146 0.27209854]
# q_rol [0.71215683 0.2878431 ]
# q_rol [0.6902332 0.3097669]
# b_rol after [0.8748524  0.12514672]
# extrinsic_value tensor(-0.6189, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.1732, grad_fn=<SumBackward0>)
# Rollout 0
# STEP 0
# y [-1.9905651  1.5861751]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# converged
# b_rol after [0.5 0.5]
# extrinsic_value tensor(-0.6931, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.1275, grad_fn=<SumBackward0>)
# STEP 1
# y [ 4.4016237 -5.371829 ]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# q_rol [0.450166 0.549834]
# q_rol [0.40168932 0.5983106 ]
# q_rol [0.35583434 0.64416564]
# b_rol after [0.10859731 0.8914027 ]
# extrinsic_value tensor(-0.6510, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.8973, grad_fn=<SumBackward0>)
# STEP 2
# y [-3.501585 -3.342414]
# b_rol [0.10859731 0.8914027 ]
# q_rol [0.31371558 0.6862844 ]
# q_rol [0.35828727 0.64171267]
# q_rol [0.3492493  0.65075064]
# q_rol [0.33008584 0.6699142 ]
# b_rol after [0.11604372 0.88395405]
# extrinsic_value tensor(-0.6342, grad_fn=<SumBackward0>)
# epistemic_value tensor(6.2577, grad_fn=<SumBackward0>)
# Rollout 0
# STEP 0
# y [-0.2115736   0.09870439]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# converged
# b_rol after [0.5 0.5]
# extrinsic_value tensor(-0.6931, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.2125, grad_fn=<SumBackward0>)
# STEP 1
# y [1.037391 5.311491]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# q_rol [0.54983395 0.450166  ]
# q_rol [0.59798956 0.40201044]
# q_rol [0.6428231 0.3571769]
# b_rol after [0.88329935 0.11670048]
# extrinsic_value tensor(-0.6518, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.5548, grad_fn=<SumBackward0>)
# STEP 2
# y [ 6.2155347 10.177026 ]
# b_rol [0.88329935 0.11670048]
# q_rol [0.6827847 0.3172153]
# q_rol [0.637978   0.36202198]
# q_rol [0.5907462  0.40925372]
# q_rol [0.54207474 0.4579253 ]
# b_rol after [0.4863721  0.51362765]
# extrinsic_value tensor(-0.6896, grad_fn=<SumBackward0>)
# epistemic_value tensor(7.6515, grad_fn=<SumBackward0>)
# big update, EFE= tensor(-13.0083, grad_fn=<DivBackward0>)
# new a [ 0.07955737 -0.07955737]
# Rollout 0
# STEP 0
# y [ 4.807733 -1.486751]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# q_rol [0.54983395 0.45016605]
# q_rol [0.5235202  0.47647983]
# q_rol [0.4945522 0.5054478]
# b_rol after [0.46629748 0.533704  ]
# extrinsic_value tensor(-0.6931, grad_fn=<SumBackward0>)
# epistemic_value tensor(6.3160, grad_fn=<SumBackward0>)
# STEP 1
# y [3.0145626 1.43908  ]
# b_rol [0.46629748 0.533704  ]
# q_rol [0.4831547 0.5168452]
# q_rol [0.5330999  0.46690014]
# q_rol [0.5457535  0.45424652]
# q_rol [0.5336064  0.46639353]
# b_rol after [0.52840155 0.4715998 ]
# extrinsic_value tensor(-0.6909, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.4491, grad_fn=<SumBackward0>)
# STEP 2
# y [ 6.842759 -4.004622]
# b_rol [0.52840155 0.4715998 ]
# q_rol [0.51419663 0.4858034 ]
# q_rol [0.56384987 0.43615004]
# q_rol [0.5894364 0.4105636]
# q_rol [0.58606756 0.4139324 ]
# b_rol after [0.6408609  0.35913906]
# extrinsic_value tensor(-0.6783, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.8438, grad_fn=<SumBackward0>)
# Rollout 0
# STEP 0
# y [-3.6298623 -1.9860263]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# q_rol [0.54983395 0.45016605]
# q_rol [0.52887994 0.47112003]
# q_rol [0.50252485 0.49747518]
# b_rol after [0.48069277 0.51930755]
# extrinsic_value tensor(-0.6931, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.1468, grad_fn=<SumBackward0>)
# STEP 1
# y [-2.319572  -3.8360066]
# b_rol [0.48069277 0.51930755]
# q_rol [0.4903475 0.5096525]
# q_rol [0.54025894 0.45974103]
# q_rol [0.5882676  0.41173235]
# q_rol [0.6320867 0.3679134]
# b_rol after [0.8526012  0.14739929]
# extrinsic_value tensor(-0.6578, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.4794, grad_fn=<SumBackward0>)
# STEP 2
# y [-4.9312882  7.5166116]
# b_rol [0.8526012  0.14739929]
# q_rol [0.66934013 0.33065996]
# q_rol [0.71201736 0.2879827 ]
# q_rol [0.74880236 0.25119767]
# q_rol [0.7770767  0.22292326]
# b_rol after [ 1.1789035  -0.17890266]
# extrinsic_value tensor(-0.5306, grad_fn=<SumBackward0>)
# epistemic_value tensor(6.5613, grad_fn=<SumBackward0>)
# Rollout 0
# STEP 0
# y [-3.8196507 -4.787961 ]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# q_rol [0.54983395 0.45016602]
# q_rol [0.56715125 0.43284878]
# q_rol [0.55770415 0.44229588]
# b_rol after [0.57803947 0.42195934]
# extrinsic_value tensor(-0.6865, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.5307, grad_fn=<SumBackward0>)
# STEP 1
# y [4.7926106 1.7447252]
# b_rol [0.57803947 0.42195934]
# q_rol [0.538941 0.461059]
# q_rol [0.5880912 0.4119088]
# q_rol [0.6035878 0.3964122]
# q_rol [0.5937314 0.4062686]
# b_rol after [0.6515357  0.34846377]
# extrinsic_value tensor(-0.6755, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.5409, grad_fn=<SumBackward0>)
# STEP 2
# y [ 2.764148 -6.133771]
# b_rol [0.6515357  0.34846377]
# q_rol [0.57519335 0.4248067 ]
# q_rol [0.5257452  0.47425482]
# q_rol [0.48705238 0.5129476 ]
# q_rol [0.4751177 0.5248823]
# b_rol after [0.4650529 0.5349476]
# extrinsic_value tensor(-0.6919, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.4891, grad_fn=<SumBackward0>)
# big update, EFE= tensor(-11.0224, grad_fn=<DivBackward0>)
# new a [ 0.00514369 -0.15397106]
# Rollout 0
# STEP 0
# y [-3.2444565  2.7264757]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# q_rol [0.45016602 0.54983395]
# q_rol [0.46692047 0.5330795 ]
# q_rol [0.49141955 0.5085805 ]
# b_rol after [0.50955385 0.49044868]
# extrinsic_value tensor(-0.6930, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.1740, grad_fn=<SumBackward0>)
# STEP 1
# y [3.9612093 0.878355 ]
# b_rol [0.50955385 0.49044868]
# q_rol [0.5047761  0.49522382]
# q_rol [0.55455816 0.44544184]
# q_rol [0.5316979  0.46830207]
# q_rol [0.504438   0.49556202]
# b_rol after [0.48531345 0.5146875 ]
# extrinsic_value tensor(-0.6931, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.1632, grad_fn=<SumBackward0>)
# STEP 2
# y [-2.179635   0.7206224]
# b_rol [0.48531345 0.5146875 ]
# q_rol [0.49265704 0.507343  ]
# q_rol [0.54255325 0.4574467 ]
# q_rol [0.52834165 0.4716584 ]
# q_rol [0.5049179  0.49508214]
# b_rol after [0.48145676 0.51854485]
# extrinsic_value tensor(-0.6931, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.5652, grad_fn=<SumBackward0>)
# Rollout 0
# STEP 0
# y [-6.2441006 -4.2418785]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# q_rol [0.54983395 0.45016602]
# q_rol [0.5687818  0.43121815]
# q_rol [0.56031483 0.43968523]
# b_rol after [0.5839233 0.4160752]
# extrinsic_value tensor(-0.6859, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.6952, grad_fn=<SumBackward0>)
# STEP 1
# y [-2.5196714  3.0596004]
# b_rol [0.5839233 0.4160752]
# q_rol [0.54186374 0.4581362 ]
# q_rol [0.59093887 0.4090611 ]
# q_rol [0.63532376 0.36467618]
# q_rol [0.67012054 0.3298794 ]
# b_rol after [0.90348977 0.09650782]
# extrinsic_value tensor(-0.6341, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.7255, grad_fn=<SumBackward0>)
# STEP 2
# y [-1.7763567   0.37271976]
# b_rol [0.90348977 0.09650782]
# q_rol [0.691466 0.308534]
# q_rol [0.732429  0.2675709]
# q_rol [0.7195252  0.28047472]
# q_rol [0.6991483  0.30085173]
# b_rol after [0.89347506 0.10652106]
# extrinsic_value tensor(-0.6116, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.4598, grad_fn=<SumBackward0>)
# Rollout 0
# STEP 0
# y [-6.0453873 -1.2502568]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# q_rol [0.54983395 0.45016605]
# q_rol [0.5283759  0.47162408]
# q_rol [0.50178874 0.4982112 ]
# b_rol after [0.4794487  0.52055085]
# extrinsic_value tensor(-0.6931, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.3013, grad_fn=<SumBackward0>)
# STEP 1
# y [-1.0950279 -3.484528 ]
# b_rol [0.4794487  0.52055085]
# q_rol [0.48972595 0.5102741 ]
# q_rol [0.5396411  0.46035898]
# q_rol [0.5238393  0.47616076]
# q_rol [0.49975726 0.50024277]
# b_rol after [0.4722094  0.52779365]
# extrinsic_value tensor(-0.6931, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.1381, grad_fn=<SumBackward0>)
# STEP 2
# y [  0.989141 -14.567172]
# b_rol [0.4722094  0.52779365]
# q_rol [0.4861075 0.5138925]
# q_rol [0.4364495 0.5635505]
# q_rol [0.3881614 0.6118386]
# q_rol [0.3422373 0.6577627]
# b_rol after [0.0751869 0.9248162]
# extrinsic_value tensor(-0.6425, grad_fn=<SumBackward0>)
# epistemic_value tensor(9.0047, grad_fn=<SumBackward0>)
# big update, EFE= tensor(-11.2236, grad_fn=<DivBackward0>)
# new a [-0.05226138 -0.21257538]
# Rollout 0
# STEP 0
# y [6.781431  4.2504163]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# q_rol [0.45016602 0.54983395]
# q_rol [0.42495096 0.5750491 ]
# q_rol [0.4289513 0.5710487]
# b_rol after [0.3905744 0.6094238]
# extrinsic_value tensor(-0.6830, grad_fn=<SumBackward0>)
# epistemic_value tensor(7.2020, grad_fn=<SumBackward0>)
# STEP 1
# y [10.616688  8.050532]
# b_rol [0.3905744 0.6094238]
# q_rol [0.445505   0.55449504]
# q_rol [0.49528778 0.5047122 ]
# q_rol [0.54451036 0.45548967]
# q_rol [0.5913777 0.4086224]
# b_rol after [0.7746614  0.22533678]
# extrinsic_value tensor(-0.6764, grad_fn=<SumBackward0>)
# epistemic_value tensor(8.3795, grad_fn=<SumBackward0>)
# STEP 2
# y [10.283342  -9.8937435]
# b_rol [0.7746614  0.22533678]
# q_rol [0.63397884 0.3660211 ]
# q_rol [0.58645386 0.41354614]
# q_rol [0.6096637  0.39033625]
# q_rol [0.635445 0.364555]
# b_rol after [0.8010459  0.19894835]
# extrinsic_value tensor(-0.6560, grad_fn=<SumBackward0>)
# epistemic_value tensor(7.6596, grad_fn=<SumBackward0>)
# Rollout 0
# STEP 0
# y [-7.537383  -6.6362963]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# q_rol [0.54983395 0.45016602]
# q_rol [0.5883162 0.4116838]
# q_rol [0.6020702  0.39792985]
# b_rol after [0.6964829  0.30351797]
# extrinsic_value tensor(-0.6722, grad_fn=<SumBackward0>)
# epistemic_value tensor(6.5347, grad_fn=<SumBackward0>)
# STEP 1
# y [7.4852743 4.4156184]
# b_rol [0.6964829  0.30351797]
# q_rol [0.59699625 0.40300375]
# q_rol [0.6440394 0.3559606]
# q_rol [0.60929424 0.3907058 ]
# q_rol [0.57457227 0.4254277 ]
# b_rol after [0.6222673  0.37773266]
# extrinsic_value tensor(-0.6820, grad_fn=<SumBackward0>)
# epistemic_value tensor(6.2933, grad_fn=<SumBackward0>)
# STEP 2
# y [-5.094171 -5.329057]
# b_rol [0.6222673  0.37773266]
# q_rol [0.56083083 0.43916914]
# q_rol [0.609339 0.390661]
# q_rol [0.65376174 0.3462382 ]
# q_rol [0.6909426  0.30905744]
# b_rol after [0.9674953  0.03250469]
# extrinsic_value tensor(-0.6183, grad_fn=<SumBackward0>)
# epistemic_value tensor(6.8435, grad_fn=<SumBackward0>)
# Rollout 0
# STEP 0
# y [-0.4623363  1.8480606]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# q_rol [0.45016605 0.54983395]
# q_rol [0.4741107 0.5258893]
# q_rol [0.5018808  0.49811912]
# b_rol after [0.52699393 0.473007  ]
# extrinsic_value tensor(-0.6931, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.2103, grad_fn=<SumBackward0>)
# STEP 1
# y [ 3.6644423 -7.731246 ]
# b_rol [0.52699393 0.473007  ]
# q_rol [0.5134935  0.48650658]
# q_rol [0.56315756 0.4368424 ]
# q_rol [0.61123216 0.38876787]
# q_rol [0.6565233  0.34347668]
# b_rol after [0.9189309  0.08106997]
# extrinsic_value tensor(-0.6433, grad_fn=<SumBackward0>)
# epistemic_value tensor(6.5048, grad_fn=<SumBackward0>)
# STEP 2
# y [-2.1703959 10.148203 ]
# b_rol [0.9189309  0.08106997]
# q_rol [0.6980145 0.3019855]
# q_rol [0.73843706 0.2615629 ]
# q_rol [0.7748918  0.22510825]
# q_rol [0.80709213 0.19290785]
# b_rol after [ 1.3107607  -0.31075984]
# extrinsic_value tensor(-0.4904, grad_fn=<SumBackward0>)
# epistemic_value tensor(6.8168, grad_fn=<SumBackward0>)
# big update, EFE= tensor(-13.5180, grad_fn=<DivBackward0>)
# new a [-0.05478252 -0.2822429 ]
# Rollout 0
# STEP 0
# y [ 2.4347992 10.676362 ]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# q_rol [0.450166   0.54983395]
# q_rol [0.40377283 0.5962272 ]
# q_rol [0.3654013  0.63459873]
# b_rol after [0.16720854 0.83279145]
# extrinsic_value tensor(-0.6565, grad_fn=<SumBackward0>)
# epistemic_value tensor(7.5589, grad_fn=<SumBackward0>)
# STEP 1
# y [ 6.797059  -1.1099845]
# b_rol [0.16720854 0.83279145]
# q_rol [0.3394866 0.6605134]
# q_rol [0.29617426 0.7038258 ]
# q_rol [0.26039356 0.73960644]
# q_rol [0.23692705 0.763073  ]
# b_rol after [-0.11334368  1.1133446 ]
# extrinsic_value tensor(-0.5475, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.4840, grad_fn=<SumBackward0>)
# STEP 2
# y [-0.49775696 -1.2265341 ]
# b_rol [-0.11334368  1.1133446 ]
# q_rol [0.22676156 0.77323836]
# q_rol [0.19361523 0.8063848 ]
# q_rol [0.18019998 0.8198    ]
# q_rol [0.18321255 0.8167874 ]
# b_rol after [-0.2136001  1.2135997]
# extrinsic_value tensor(-0.4762, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.2439, grad_fn=<SumBackward0>)
# Rollout 0
# STEP 0
# y [-8.943057  9.089167]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# q_rol [0.45016602 0.54983395]
# q_rol [0.40912032 0.5908797 ]
# q_rol [0.38904822 0.6109518 ]
# b_rol after [0.2734724 0.7265254]
# extrinsic_value tensor(-0.6683, grad_fn=<SumBackward0>)
# epistemic_value tensor(7.1838, grad_fn=<SumBackward0>)
# STEP 1
# y [-0.22046852 -2.1066432 ]
# b_rol [0.2734724 0.7265254]
# q_rol [0.3886351  0.61136484]
# q_rol [0.34230196 0.6576981 ]
# q_rol [0.36840746 0.6315926 ]
# q_rol [0.39709842 0.6029016 ]
# b_rol after [0.31351024 0.6864847 ]
# extrinsic_value tensor(-0.6718, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.5411, grad_fn=<SumBackward0>)
# STEP 2
# y [10.474027   1.3297958]
# b_rol [0.31351024 0.6864847 ]
# q_rol [0.4078225 0.5921775]
# q_rol [0.3605508 0.6394492]
# q_rol [0.316767 0.683233]
# q_rol [0.27787614 0.72212386]
# b_rol after [-0.06284391  1.0628388 ]
# extrinsic_value tensor(-0.5909, grad_fn=<SumBackward0>)
# epistemic_value tensor(6.5168, grad_fn=<SumBackward0>)
# Rollout 0
# STEP 0
# y [-6.3414564 -4.929275 ]
# b_rol [0.5 0.5]
# q_rol [0.5 0.5]
# q_rol [0.54983395 0.45016602]
# q_rol [0.59076816 0.40923187]
# q_rol [0.61053306 0.38946688]
# b_rol after [0.7250326  0.27496633]
# extrinsic_value tensor(-0.6685, grad_fn=<SumBackward0>)
# epistemic_value tensor(5.9499, grad_fn=<SumBackward0>)
# STEP 1
# y [-4.0800705 -3.8861487]
# b_rol [0.7250326  0.27496633]
# q_rol [0.610655   0.38934502]
# q_rol [0.56219286 0.43780717]
# q_rol [0.53545284 0.4645471 ]
# q_rol [0.5393463  0.46065375]
# b_rol after [0.612732   0.38726726]
# extrinsic_value tensor(-0.6900, grad_fn=<SumBackward0>)
# epistemic_value tensor(6.4082, grad_fn=<SumBackward0>)
# STEP 2
# y [-5.4728127  -0.47544426]
# b_rol [0.612732   0.38726726]
# q_rol [0.55612856 0.44387135]
# q_rol [0.6047854  0.39521462]
# q_rol [0.5687855  0.43121442]
# q_rol [0.53329927 0.46670067]
# b_rol after [0.53804    0.46195522]
# extrinsic_value tensor(-0.6909, grad_fn=<SumBackward0>)
# epistemic_value tensor(6.4994, grad_fn=<SumBackward0>)
# big update, EFE= tensor(-12.3262, grad_fn=<DivBackward0>)
# new a [-0.03800427 -0.36176062]

# %%
p = torch.tensor([0.5, 0.5])
- (p*p.log2()).sum()
# Out:
# tensor(1.)

# %%
p.log().mean()
# Out:
# tensor(-5.7565)
